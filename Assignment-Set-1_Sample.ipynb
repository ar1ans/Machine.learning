# %%
# !hostname
# !whoami
# Out:
# aryan.local
# a

# %%
import sys
from datetime import datetime
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn

# %%
print(datetime.now(), time.localtime().tm_zone, 'UTC')
# Out:
# 2021-11-21 05:37:42.643301 +0330 UTC

# %%
sys.version
# Out:
# '3.8.8 (default, Apr 13 2021, 12:59:45) \n[Clang 10.0.0 ]'

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': 0.3*np.random.randn(500)}
data['b'] = data['a'] + 10 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
df = pd.DataFrame(np.random.randn(10, 4)) 
print(df)

j=1.23
for i in range(80000000):
  j+=j**0.8157678

print("\n-> Execution time was %s seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3
# 0  0.081316 -0.367765  1.107700 -0.176309
# 1 -0.539815 -0.036370 -0.947873 -0.124176
# 2  2.414529 -1.203097  0.277803 -0.027390
# 3  1.797373 -0.721024 -0.231262  0.356052
# 4 -1.417493 -0.865785 -1.246902 -1.718674
# 5  1.185648  1.356875  1.881941 -0.329057
# 6 -2.411660  0.647530  0.193978 -0.020808
# 7 -1.935486  1.163502 -0.189430  0.835745
# 8  0.511835 -0.599890  0.384986  1.561160
# 9 -0.039433  1.181371 -0.217405  0.421508
#
# -> Execution time was 16.4979031085968 seconds <-
